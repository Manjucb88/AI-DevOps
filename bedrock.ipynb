# %% [markdown]
# <a href="https://colab.research.google.com/github/Manjucb88/AI-DevOps/blob/main/bedrock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install boto3

import boto3
import os
import json
# Out:
# Requirement already satisfied: boto3 in /usr/local/lib/python3.12/dist-packages (1.41.2)
# Requirement already satisfied: botocore<1.42.0,>=1.41.2 in /usr/local/lib/python3.12/dist-packages (from boto3) (1.41.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.16.0,>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from boto3) (0.15.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.42.0,>=1.41.2->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore<1.42.0,>=1.41.2->boto3) (2.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.42.0,>=1.41.2->boto3) (1.17.0)

# %%
os.environ["AWS_ACCESS_KEY_ID"] = "AKIAQWTJCX4LIE7VHFUW"
os.environ["AWS_SECRET_ACCESS_KEY"] = "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"

# %%
#check sk and ak
service_sts = boto3.client('sts')
print(service_sts.get_caller_identity())
# Out:
# {'UserId': 'AIDAQWTJCX4LGVNUPGD4Y', 'Account': '048538763030', 'Arn': 'arn:aws:iam::048538763030:user/gen-ai-user', 'ResponseMetadata': {'RequestId': '68c23a99-6627-4506-89be-79815495216a', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '68c23a99-6627-4506-89be-79815495216a', 'x-amz-sts-extended-request-id': 'MTp1cy1lYXN0LTE6UzoxNzYzODEwODgyMjI1Okc6bHlYOWRqOGg=', 'content-type': 'text/xml', 'content-length': '408', 'date': 'Sat, 22 Nov 2025 11:28:02 GMT'}, 'RetryAttempts': 0}}

# %%
#connect to bedrock service
service_client = boto3.client(service_name="bedrock-runtime", region_name="us-east-1")

# %%
input_request = {
    "inputText": "little motivation stories",
    "textGenerationConfig": {
        "temperature": 0.7,
        "topP": 0.9,
        "maxTokenCount": 50,
    }
}

# %%
print(type(input_request))
# Out:
# <class 'dict'>

# %%
input_json_request = json.dumps(input_request)
print(type(input_json_request))
# Out:
# <class 'str'>

# %%
response = service_client.invoke_model(
    modelId="amazon.titan-text-express-v1",
    contentType="application/json",
    body=input_json_request,
    accept="application/json"
)

# %%
print(response)
# Out:
# {'ResponseMetadata': {'RequestId': '122a5321-20f4-45b1-86e7-39848683fac1', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sat, 22 Nov 2025 11:28:05 GMT', 'content-type': 'application/json', 'content-length': '350', 'connection': 'keep-alive', 'x-amzn-requestid': '122a5321-20f4-45b1-86e7-39848683fac1', 'x-amzn-bedrock-invocation-latency': '2566', 'x-amzn-bedrock-output-token-count': '50', 'x-amzn-bedrock-input-token-count': '3'}, 'RetryAttempts': 0}, 'contentType': 'application/json', 'body': <botocore.response.StreamingBody object at 0x7e533dcbbe80>}

# %%
print(response.keys())
# Out:
# dict_keys(['ResponseMetadata', 'contentType', 'body'])

# %%
print(type(response['body']))
# Out:
# <class 'botocore.response.StreamingBody'>

# %%
result = json.loads(response["body"].read())

# %%
print(result)
print(type(result))
# Out:
# {'inputTextTokenCount': 3, 'results': [{'tokenCount': 50, 'outputText': '\nOnce upon a time, there was a young man named John who had a dream of becoming a successful entrepreneur. In order to achieve his goal, John worked tirelessly, putting in long hours and sacrificing many of his personal interests. Despite his efforts', 'completionReason': 'LENGTH'}]}
# <class 'dict'>

# %%
print(result['results'][0]['outputText'])
# Out:
# Once upon a time, there was a young man named John who had a dream of becoming a successful entrepreneur. In order to achieve his goal, John worked tirelessly, putting in long hours and sacrificing many of his personal interests. Despite his efforts
